# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")
response = ollama.chat.completions.create(model="phi3", messages=[{"role":"user", "content": "what is 2+2?"}])
print(response.choices[0].message.content)
# Out:
# The answer to the question "What is 2+2?" using basic arithmetic operations for addition. The sum of two plus two equals four, so the result is 4.

# %%
openai = OpenAI()
response = openai.chat.completions.create(model="gpt-4o-mini", messages=[{"role":"user", "content": "what is 2+2?"}])
print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A train leaves a station traveling east at 60 miles per hour. At the same time, another train leaves a station 240 miles west of the first station, traveling west at 75 miles per hour. How far apart will the two trains be one hour after they leave their respective stations?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# To find the distance between the two trains one hour after they leave their stations, we start by calculating the distance traveled by each train in that hour.
#
# 1. **Train A** (traveling east from the first station):
#    - Speed: 60 miles per hour
#    - Time: 1 hour
#    - Distance traveled by Train A = Speed × Time = 60 miles/hour × 1 hour = 60 miles.
#
# 2. **Train B** (traveling west from the second station):
#    - Speed: 75 miles per hour
#    - Time: 1 hour
#    - Distance traveled by Train B = Speed × Time = 75 miles/hour × 1 hour = 75 miles.
#
# Next, we determine how far apart the two trains are after one hour.
#
# - Initially, the distance between the two trains is 240 miles (the distance between the two stations).
# - After one hour, Train A has moved 60 miles east, and Train B has moved 75 miles west.
#
# Since they are moving away from each other, we can calculate the new distance between them:
#
# \[
# \text{Distance after 1 hour} = \text{Initial distance} + \text{Distance traveled by Train A} + \text{Distance traveled by Train B}
# \]
#
# Substituting in the values we have:
#
# \[
# \text{Distance after 1 hour} = 240 \text{ miles} + 60 \text{ miles} + 75 \text{ miles}
# \]
#
# Calculating the total:
#
# \[
# \text{Distance after 1 hour} = 240 + 60 + 75 = 375 \text{ miles}
# \]
#
# Therefore, the two trains will be **375 miles apart** one hour after they leave their respective stations.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# To find the distance between the two trains one hour after they leave their stations, we start by calculating the distance traveled by each train in that hour.
#
# 1. **Train A** (traveling east from the first station):
#    - Speed: 60 miles per hour
#    - Time: 1 hour
#    - Distance traveled by Train A = Speed × Time = 60 miles/hour × 1 hour = 60 miles.
#
# 2. **Train B** (traveling west from the second station):
#    - Speed: 75 miles per hour
#    - Time: 1 hour
#    - Distance traveled by Train B = Speed × Time = 75 miles/hour × 1 hour = 75 miles.
#
# Next, we determine how far apart the two trains are after one hour.
#
# - Initially, the distance between the two trains is 240 miles (the distance between the two stations).
# - After one hour, Train A has moved 60 miles east, and Train B has moved 75 miles west.
#
# Since they are moving away from each other, we can calculate the new distance between them:
#
# \[
# \text{Distance after 1 hour} = \text{Initial distance} + \text{Distance traveled by Train A} + \text{Distance traveled by Train B}
# \]
#
# Substituting in the values we have:
#
# \[
# \text{Distance after 1 hour} = 240 \text{ miles} + 60 \text{ miles} + 75 \text{ miles}
# \]
#
# Calculating the total:
#
# \[
# \text{Distance after 1 hour} = 240 + 60 + 75 = 375 \text{ miles}
# \]
#
# Therefore, the two trains will be **375 miles apart** one hour after they leave their respective stations.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Can you give me a business area that is ripe for an Agentic AI solution?"}]

# Then make the first call:

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# One business area that could greatly benefit from an Agentive AI solution is:
#
# **Customer Service and Quality Monitoring**
#
# In this industry, Agentive AI can be applied to develop intelligent systems that proactively monitor customer interactions across multiple channels (e.g., phone, email, chatbots). These systems can:
#
# 1. **Analyze sentiment and emotions**: Detect changes in a customer's emotional state, enabling human agents to respond more empathetically.
# 2. **Predict customer intent**: Identify the root cause of a customer's concern, allowing agents to provide more targeted support.
# 3. **Automate routine inquiries**: Use predictive models to handle simple, repeatable questions, freeing up agents for more complex issues.
# 4. **Identify and address potential issues**: Proactively detect warning signs of escalation or dissatisfaction, enabling proactive resolution.
#
# By leveraging Agentive AI in customer service, companies can:
#
# 1. Enhance customer experience with more personalized support
# 2. Reduce response times and resolution time
# 3. Improve first-call resolution (FCR) rates
# 4. Decrease the need for escalations to higher-level agents
#
# Other potential application areas for Agentive AI in customer service could include:
#
# * **Chatbot optimization**: Automatically adjusting chatbot responses, conversation flow, or user routing.
# * **Sentiment analysis**: Analyzing customers' feedback and sentiment trends, enabling data-driven decision-making.
# * **Root cause analysis (RCA)**: Identifying the underlying cause of repeated issue patterns to optimize service delivery.
#
# Agentive AI can be applied in other domains as well, such as:
#
# * Healthcare: Predicting patient outcomes, streamlining clinical workflows, or identifying potential adverse events.
# * Supply Chain Management: Proactively detecting supply chain disruptions, optimizing inventory management, and improving logistics flow.
# * Cybersecurity: Detecting threats, predicting attack patterns, or mitigating vulnerability risks.
#
# When exploring an Agentive AI solution, consider the following:
#
# 1. **Identify specific pain points**: Pinpoint areas where an intelligent system can directly address inefficiencies or challenges faced by your business.
# 2. **Assess competitive landscape**: Research existing solutions in your industry and understand how Agentive AI compares to traditional approaches.
# 3. **Gather stakeholder input**: Collaborate with team members, customers, or partners to validate the need for an Agentive AI solution.
#
# By leveraging Agentive AI effectively, businesses can drive significant improvements in efficiency, accuracy, and customer satisfaction.

# %%
messages = [{"role": "user", "content": "What is the bigest pain point in Customer Service and Quality Monitoring?"}]

# Then make the first call:

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)

# Then read the business idea:

pain_point = response.choices[0].message.content
print(pain_point)
# Out:
# Based on industry trends and research, some of the biggest pain points in Customer Service and Quality Monitoring are:
#
# 1. **Staffing shortages and talent acquisition**: Hiring and retaining skilled customer service representatives can be challenging, particularly during peak periods or when dealing with high volumes of incoming inquiries.
# 2. **Training and upskilling**: Ensuring that customer service staff have the necessary skills and knowledge to resolve complex issues and navigate new technologies is a significant challenge.
# 3. **Metrics and key performance indicators (KPIs)**: Defining and tracking relevant metrics for customer satisfaction, first response times, and overall quality can be difficult, particularly in industries with high variability or complex issue resolution processes.
# 4. **Inefficiencies in process management**: Manual processes, such as reviewing and routing multiple touchpoints without automation, can lead to increased costs and decreased efficiency.
# 5. **Employee engagement and burnout**: The constant need for employee self-care when dealing with issues affecting customers' lives may cause strain on staff at their emotional limits.
#
# That said, research indicates the biggest pain point in these two areas is:
#
# *   **Staffing shortages and talent acquisition**
#
# The primary reasons behind this issue include:
#
# 1.  **Skill gaps**: Finding representatives skilled in resolving complex customer issues or adopting new technologies to improve processes.
# 2.  **Increased demand for support**: The rise in digital interactions, particularly for customers making multiple inquiries through various channels like chatbot calls, phone numbers, more complicated technical questions from a vast array and varying needs within their industry.
#
# To address these pain points, organizations can:
#
# *   Implement data-driven process optimization to streamline operations
# *   Offer employee training and upskilling programs
# *   Develop metrics and KPIs that align with business goals
#
# Ultimately, identifying the right pain point is crucial for your own context to determine what will best be able to effectively tackle those problem areas.
#
# While all these are valid points and solutions provided here, we need a more definitive solution to get better and improve quality in Customer Service.

# %%
messages = [{"role": "user", "content": "Suggest an Agentic AI solution for " + pain_point + "?"}]

# Then make the first call:

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages
)

# Then read the business idea:

agenticsolution = response.choices[0].message.content
print(agenticsolution)
# Out:
# Based on industry trends and research, an Agentic AI solution can help address the pain point of staffing shortages and talent acquisition in customer service. Here's a comprehensive approach to tackle this challenge:
#
# **Agentic AI Solution:**
#
# 1.  **Automated Issue Routing**: Implement AI-powered chatbots or virtual assistants that can handle routine inquiries, freeing up human representatives for more complex issues.
# 2.  **Intelligent Answer Generation**: Utilize AI-driven content generation tools to provide instant, accurate answers to common customer questions, reducing the workload on human representatives.
# 3.  **Predictive Modeling for Talent Acquisition**: Develop predictive models using machine learning algorithms to identify potential candidates with the skills and expertise required for the role, streamlining the hiring process.
# 4.  **Upskilling and Reskilling Training**: Offer AI-powered training platforms that can personalize content and pace to individual employee needs, ensuring they stay up-to-date with industry developments and best practices.
#
# **Implementation Roadmap:**
#
# 1.  Conduct a thorough analysis of current processes, customer interactions, and existing technology infrastructure to identify opportunities for improvement.
# 2.  Develop a project plan and timeline for implementation, incorporating phased rollout to minimize disruptions to existing services.
# 3.  Establish a multi-stakeholder team comprising representatives from IT, HR, sales, and marketing to manage the transition from legacy systems to AI-powered solutions.
#
# **Key Performance Indicators (KPIs):**
#
# 1.  **Time-to-Resolution**: Measuring the time taken for customer inquiries to be resolved by human representatives or AI systems.
# 2.  **Accuracy of Answer Generation**: Evaluating the accuracy and relevance of answers provided by AI-driven content generation tools.
# 3.  **Talent Acquisition Effectiveness**: Assessing the success of predictive modeling in identifying suitable candidates for specific roles.
#
# While no solution can fully eliminate staffing shortages, implementing an Agentic AI approach can help alleviate strain on customer service resources while improving the overall quality of experiences offered to customers.

# %%
from IPython.display import Markdown, display

display(Markdown(agenticsolution))
# Out:
# Based on industry trends and research, an Agentic AI solution can help address the pain point of staffing shortages and talent acquisition in customer service. Here's a comprehensive approach to tackle this challenge:
#
# **Agentic AI Solution:**
#
# 1.  **Automated Issue Routing**: Implement AI-powered chatbots or virtual assistants that can handle routine inquiries, freeing up human representatives for more complex issues.
# 2.  **Intelligent Answer Generation**: Utilize AI-driven content generation tools to provide instant, accurate answers to common customer questions, reducing the workload on human representatives.
# 3.  **Predictive Modeling for Talent Acquisition**: Develop predictive models using machine learning algorithms to identify potential candidates with the skills and expertise required for the role, streamlining the hiring process.
# 4.  **Upskilling and Reskilling Training**: Offer AI-powered training platforms that can personalize content and pace to individual employee needs, ensuring they stay up-to-date with industry developments and best practices.
#
# **Implementation Roadmap:**
#
# 1.  Conduct a thorough analysis of current processes, customer interactions, and existing technology infrastructure to identify opportunities for improvement.
# 2.  Develop a project plan and timeline for implementation, incorporating phased rollout to minimize disruptions to existing services.
# 3.  Establish a multi-stakeholder team comprising representatives from IT, HR, sales, and marketing to manage the transition from legacy systems to AI-powered solutions.
#
# **Key Performance Indicators (KPIs):**
#
# 1.  **Time-to-Resolution**: Measuring the time taken for customer inquiries to be resolved by human representatives or AI systems.
# 2.  **Accuracy of Answer Generation**: Evaluating the accuracy and relevance of answers provided by AI-driven content generation tools.
# 3.  **Talent Acquisition Effectiveness**: Assessing the success of predictive modeling in identifying suitable candidates for specific roles.
#
# While no solution can fully eliminate staffing shortages, implementing an Agentic AI approach can help alleviate strain on customer service resources while improving the overall quality of experiences offered to customers.
